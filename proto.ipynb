# %% [markdown]
# ## List of API

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
import pandas as pd

# %% [markdown]
# ### Send email

# %%
to = "arpit.goel@xyz.com"
subject = "Test Email"
body = "This is a test email sent using Python."

# %% [markdown]
# ## Prototyping

# %% [markdown]
# ### Gmail API

# %%
# GMAIL prototype

# %% [markdown]
# ### Microsoft Graph API

# %%
# Graph API prototyp
